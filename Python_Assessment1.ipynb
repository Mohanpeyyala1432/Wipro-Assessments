# %% [markdown]
# 1. Write a program to take your name as input and print a greeting message.

# %%
name="mohan"

print("welcome to wipro training "+name)
# Out:
# welcome to wipro training mohan

# %% [markdown]
# 2. Take two numbers as input and print their sum.

# %%
num1=10

num2=20

print("addition of two numbers is ",num1+num2)
# Out:
# addition of two numbers is  30

# %% [markdown]
# 3.Write a program to check the data type of a variable entered by the user.

# %%
age=int(input("enter your age"))

print(type(age))
# Out:
# enter your age25
# <class 'int'>

# %% [markdown]
# 4. Take a string input and print it in uppercase and lowercase.

# %%
msg="hey hello" #lower case to upper case

print(msg.upper())
# Out:
# HEY HELLO

# %%
msg="HEY MOHAN" # upper case to lower case

print(msg.lower())
# Out:
# hey mohan

# %% [markdown]
# 5. Write a program to count the number of characters in a string.

# %%
country="India"

print(len(country)) # number of characters in a string
# Out:
# 5

# %% [markdown]
# 6. Take a string and replace all spaces with underscores (_).

# %%
address=" vishakha patnam AP 531033"

print(address.replace(" ","_"))
# Out:
# _vishakha_patnam_AP_531033

# %% [markdown]
# 7.Write a program to extract the first and last character of a string.

# %%
item="laptop"

print(item[0], item[-1])
# Out:
# l p

# %% [markdown]
# 8. Take user input and print it using formatted string (f-string).

# %%
name=input("enter your name ")

age=int(input("enter your age "))

print(f"my name is {name} and my age is {age}")
# Out:
# enter your name mohan
# enter your age 23
# my name is mohan and my age is 23

# %% [markdown]
# 9.Write a program to concatenate two strings entered by the user.

# %%
food_item1=input("enter your first faviroute food name ")

food_item2=input("enter your second faviroute food name ")

print(food_item1+food_item2)
# Out:
# enter your first faviroute food name chicken biryani
# enter your second faviroute food name mutton biryani
# chicken biryanimutton biryani

# %% [markdown]
# 10.Take a sentence and remove leading and trailing spaces.

# %%
sentence="  hey how are you! i am fine what about you  "

print(sentence.strip())
# Out:
# hey how are you! i am fine what about you

# %% [markdown]
# 11.Banking: Take customer name and account balance, and print a welcome message with balance.

# %%
customer_name="mohan"

balance=15000

print(f"welcome to Indian Overseas Bank your account balance is {balance} rupees")
# Out:
# welcome to Indian Overseas Bank your account balance is 15000 rupees

# %% [markdown]
# 12.E-commerce: Take product name and price, apply 10% discount and print final price.

# %%
product_name="asus laptop"

price=50000

discount=10

final_price=price*discount/100

print(final_price)
# Out:
# 5000.0

# %% [markdown]
# 13.Healthcare: Take patient name and age, print formatted health record message.

# %%
patient_name="abhi"

patient_age=26

print(f"hey {patient_name} your health is now ok you can go")
# Out:
# hey abhi your health is now ok you can go

# %% [markdown]
# 14.Education: Take student name and marks, print a formatted report.

# %%
sname=input("enter student name ")

marks=int(input("enter marks"))

print("student report")

print(sname, marks)
# Out:
# enter student name mohan
# enter marks98
# student report
# mohan 98

# %% [markdown]
# 15.Travel: Take city name and print a welcome message in uppercase.

# %%
city="vizag"

message="Welcome to the City of Destiny "

print(message.upper(),city.upper())
# Out:
# WELCOME TO THE CITY OF DESTINY  VIZAG

# %% [markdown]
# 16.HR System: Take employee name and role, print a formatted introduction.

# %%
emp_name="cherry"

role="cloud developer"

print(f"hey {emp_name} we are offering you as a {role}")
# Out:
# hey cherry we are offering you as a cloud developer

# %% [markdown]
# 17.Food Delivery: Take food item and quantity, print order summary.

# %%
food_item="biryani"

quantity=2

print(f" {quantity} {food_item}'s has been delivered successfully")
# Out:
#  2 biryani's has been delivered successfully

# %% [markdown]
# 18.Login System: Take username and remove extra spaces using strip().

# %%
username=input("enter your name")

print(username.strip())
# Out:
# enter your name    mohan
# mohan

# %% [markdown]
# 19.Data Cleaning: Take a string and replace special characters (#, @) with empty string.

# %%
string="#moh@an"

print(string.replace("@","").replace("#",""))
# Out:
# mohan

# %% [markdown]
# 20.Chat Application: Take user message and print it in title case.

# %%
message=input("enter your message here ")

print(message.title())
# Out:
# enter your message here hey how are you
# Hey How Are You
